# %% [markdown]
# <a href="https://colab.research.google.com/github/isislavor/dataset-monitoria-etica-2025/blob/main/Artigo_%C3%89tica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

sns.set(style="whitegrid")

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a8dd971-76c3-400d-8f46-f93c04dd85af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a8dd971-76c3-400d-8f46-f93c04dd85af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded.keys()
# Out:
# dict_keys(['Questionário de avaliação de atividade prática - Ética profissional_2025_2 (respostas) - Respostas ao formulário 1 (4).csv', 'Questionário de avaliação de atividade prática - Ética profissional (respostas) - Respostas ao formulário 1 (5).csv'])

# %%
df1 = pd.read_csv("Questionário de avaliação de atividade prática - Ética profissional_2025_2 (respostas) - Respostas ao formulário 1 (3).csv")
df2 = pd.read_csv("Questionário de avaliação de atividade prática - Ética profissional (respostas) - Respostas ao formulário 1 (4).csv")

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
print("Total de respostas:", len(df))
# Out:
# Total de respostas: 20

# %%
if "Carimbo de data/hora" in df.columns:
    df = df.drop(columns=["Carimbo de data/hora"])

# %%
col_eng = "Como você avaliaria seu grau de engajamento durante o desenvolvimento do projeto?"

df[col_eng].value_counts().plot(kind="bar")

plt.title("Engajamento dos estudantes")
plt.ylabel("Frequência")
plt.show()

# %%
motivos = [
"Impacto na vida das pessoas",
"Impacto para várias pessoas",
"Criação de valor",
"Abordagem de um problema social",
"Interesse pessoal no tema",
"Interesse da equipe no tema",
"Grande potencial de discussão ética",
"Tema pouco explorado em jogos"
]

# %%
for col in motivos:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
df[motivos].mean().sort_values().plot(kind="barh")

plt.title("Importância média dos motivos")
plt.show()

# %%
col_dif = "Quais foram as maiores dificuldades encontradas no desenvolvimento do jogo?"

dif = df[col_dif].dropna().str.split(", ").explode()

freq = dif.value_counts()

plt.figure(figsize=(10,6))

freq.plot(kind="barh", color="steelblue")

plt.title("Principais dificuldades no desenvolvimento do jogo")
plt.xlabel("Número de estudantes")
plt.ylabel("")

# adicionar valores nas barras
for i, v in enumerate(freq):
    plt.text(v + 0.1, i, str(v), va='center')

plt.tight_layout()
plt.show()

# %%
etapas = [
"Etapa 1 – Pesquisa e resumo do tema",
"Etapa 2 – Identificação das TAGs",
"Etapa 3 – Escolha do gênero do jogo",
"Etapa 4 – Criação do universo narrativo (lore, espaço, personagens)",
"Etapa 5 – Criação das regras e protótipo do jogo",
"Etapa 6 – Testes e ajustes",
"Etapa 7 – Produção da apresentação (slides e exposição)",
"Etapa 8 – Apresentação final"
]

# %%
for col in etapas:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
df[etapas].mean().sort_values().plot(kind="barh")

plt.title("Dificuldade média das etapas")
plt.show()

# %%
plt.figure(figsize=(14,6))

sns.boxplot(data=df[etapas])

plt.xticks(rotation=45, fontsize=9)
plt.title("Distribuição das avaliações das etapas")
plt.ylabel("Classificação")

plt.tight_layout()
plt.show()

# %%
df["O que mais você aprendeu com essa experiência?"].dropna().tolist()
# Out:
# ['Jogando o jogo dos outros e produzindo o meu, aprendi bastante sobre o conteúdo e me diverti muito nas aulas, além de melhorar a habilidade de comunicação e trabalho em equipe',
#  'Trabalho em equipe',
#  'aprendi que por mais q o tema n seja muito relevante, sempre devemos levar em conta que foi bastante util e muito bem explorado ',
#  '.',
#  'Importância do trabalho em equipe e uma melhor distribuição de funções dentro dela.',
#  'Aprendi muito sobre nosso tema, além de ser muito legal e divertido criar um jogo em equipe, é uma experiência muito legal e que conseguimos aprender muitas coisas ao longo do processo.',
#  'Trabalho em equipe, criatividade, foco na hora de fazer as regras.',
#  'A importância de projetar bem, para que no futuro mudanças muito bruscas não precisem ser feitas.',
#  'Eu tenho que rever com quem que faço equipe de trabalho, gostei do tema, aprendi mais sobre coisas que nem sabia',
# ...

# %%
df["Sugestões de melhoria para futuras edições da atividade:"].dropna().tolist()
# Out:
# ['Clareza maior na explicação dos itens do sorteio é um pouco mais de tempo, já que não deu para concluir quase nenhum dos jogos ',
#  'Ter mais tempo para criar, pois no final do semestre é muito corrido.',
#  'talvez uma melhor organizaçao na hora de apresentar',
#  '.',
#  'Talvez uma flexibilidade maior, a possíveis problemas que venham a surgir.',
#  'Sem sugestões.',
#  'Nenhuma.',
#  'Mais tempo, tá tudo ótimo, só que o jogo demanda mais tempo, eu gostaria de ter feito um jogo muito melhor, mas não tinha tempo, pq tbm né, todos os professores deixaram para passar trabalho no final do mês, enfim eu gostei das atividades muito massa',
#  'Usar algum jogo como portifólio, pedir o esquema do jogo e ou como foi criado para servir de exemplo ',
#  'Está tudo ok',
#  'ta bom assim']

# %%
col_aprendizado = "O que mais você aprendeu com essa experiência?"

tabela_respostas = df[col_aprendizado].dropna().reset_index(drop=True)

tabela_respostas
# Out:
# 0     Jogando o jogo dos outros e produzindo o meu, ...
# 1                                    Trabalho em equipe
# 2     aprendi que por mais q o tema n seja muito rel...
# 3                                                     .
# 4     Importância do trabalho em equipe e uma melhor...
# 5     Aprendi muito sobre nosso tema, além de ser mu...
# 6     Trabalho em equipe, criatividade, foco na hora...
# 7     A importância de projetar bem, para que no fut...
# 8     Eu tenho que rever com quem que faço equipe de...
# 9     A necessidade de dividir de maneira ordeira o ...
# 10                                  A ser mais creativo
# 11                      como criar um jogo de tabuleiro
# Name: O que mais você aprendeu com essa experiência?, dtype: object

# %%
tabela_respostas = pd.DataFrame({
    "Resposta dos estudantes": df[col_aprendizado].dropna()
})

tabela_respostas
# Out:
#                               Resposta dos estudantes
# 0   Jogando o jogo dos outros e produzindo o meu, ...
# 3                                  Trabalho em equipe
# 4   aprendi que por mais q o tema n seja muito rel...
# 6                                                   .
# 7   Importância do trabalho em equipe e uma melhor...
# 8   Aprendi muito sobre nosso tema, além de ser mu...
# 9   Trabalho em equipe, criatividade, foco na hora...
# 10  A importância de projetar bem, para que no fut...
# 14  Eu tenho que rever com quem que faço equipe de...
# 16  A necessidade de dividir de maneira ordeira o ...
# 17                                A ser mais creativo
# 18                    como criar um jogo de tabuleiro

# %%
def categorizar(texto):

    texto = str(texto).lower()

    if "ética" in texto or "ético" in texto:
        return "Aprendizado ético"

    if "equipe" in texto or "grupo" in texto:
        return "Trabalho em equipe"

    if "criatividade," in texto or "criar" in texto:
        return "Criatividade"

    if "jogo" in texto or "mecânica" in texto:
        return "Desenvolvimento de jogos"

    return "Outros"

# %%
df["Categoria_aprendizado"] = df[col_aprendizado].apply(categorizar)

# %%
df["Categoria_aprendizado"].value_counts()
# Out:
# Categoria_aprendizado
# Outros                13
# Trabalho em equipe     6
# Criatividade           1
# Name: count, dtype: int64

# %%
pd.DataFrame(
    df["Categoria_aprendizado"].value_counts()
).rename(columns={"Categoria_aprendizado":"Frequência"})
# Out:
#                        count
# Categoria_aprendizado
# Outros                    13
# Trabalho em equipe         6
# Criatividade               1

# %%
def categorizar_aprendizado(texto):

    texto = str(texto).lower()

    # trabalho em equipe
    if "equipe" in texto or "grupo" in texto or "comunicação" in texto:
        return "Trabalho em equipe"

    # criação de jogos
    if "jogo" in texto or "tabuleiro" in texto or "regras" in texto:
        return "Criação de jogos"

    # criatividade
    if "criativ" in texto:
        return "Criatividade"

    # planejamento / organização
    if "tempo" in texto or "projet" in texto or "planej" in texto:
        return "Planejamento do projeto"

    # aprendizado sobre o tema
    if "tema" in texto or "conteúdo" in texto or "aprendi" in texto:
        return "Aprendizado sobre o tema"

    # diversão / experiência
    if "divert" in texto or "legal" in texto:
        return "Experiência positiva"

    return "Outros"

# %%
df["Categoria_aprendizado"] = df[col_aprendizado].apply(categorizar_aprendizado)

# %%
df["Categoria_aprendizado"].value_counts()
# Out:
# Categoria_aprendizado
# Outros                      10
# Trabalho em equipe           6
# Planejamento do projeto      2
# Aprendizado sobre o tema     1
# Criação de jogos             1
# Name: count, dtype: int64

# %%
sns.countplot(
    data=df,
    x="Categoria_aprendizado",
    order=df["Categoria_aprendizado"].value_counts().index
)

plt.title("Principais aprendizados relatados pelos estudantes")
plt.xlabel("Categoria")
plt.ylabel("Frequência")
plt.xticks(rotation=30)
plt.show()

# %%
tabela = pd.DataFrame(
    df["Categoria_aprendizado"].value_counts()
)

tabela.columns = ["Frequência"]
tabela
# Out:
#                           Frequência
# Categoria_aprendizado
# Outros                            10
# Trabalho em equipe                 6
# Planejamento do projeto            2
# Aprendizado sobre o tema           1
# Criação de jogos                   1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_854/1063111091.py in <cell line: 0>()
# ----> 1 freq_dificuldades = dificuldades.value_counts()
#       2
#       3 plt.figure(figsize=(10,6))
#       4
#       5 sns.barplot(
#
# NameError: name 'dificuldades' is not defined

# %% [markdown]
# As respostas abertas foram analisadas por meio de categorização temática. Os principais aprendizados relatados pelos estudantes concentraram-se em aspectos relacionados ao trabalho em equipe, à criação de jogos e ao planejamento do projeto, indicando que a atividade contribuiu tanto para o desenvolvimento de habilidades técnicas quanto colaborativas.
